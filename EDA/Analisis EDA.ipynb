# %% [markdown]
# # **PI**

# %%
# Importamos las librerías que estaremos utilizando

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargamos el dataset
datavuelos = pd.read_csv("flights_2020.csv", names=['YEAR', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER', 'ORIGIN_CITY_NAME',
'ORIGIN_STATE_ABR', 'DEST_CITY_NAME', 'DEST_STATE_ABR', 'CRS_DEP_TIME', 'DEP_DELAY_NEW',
'CRS_ARR_TIME', 'ARR_DELAY_NEW', 'CANCELLED', 'CANCELLATION_CODE', 'AIR_TIME', 'DISTANCE'])

# %%
#Se cargo el dataset ya filtrado y guardado en csv
#datavuelos=pd.read_csv('Vuelos2020Mejorado.csv')

# %%
datavuelos.drop('Unnamed: 0', inplace=True, axis=1)

# %%
datavuelos
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        2020      1            17            5                WN
# 1        2020      1            17            5                WN
# 2        2020      1            17            5                WN
# 3        2020      1            17            5                WN
# 4        2020      1            17            5                WN
# ...       ...    ...           ...          ...               ...
# 4316992  2020     11            22            7                WN
# 4316993  2020     11            22            7                WN
# 4316994  2020     11            22            7                WN
# 4316995  2020     11            22            7                WN
# 4316996  2020     11            22            7                WN
#
#         ORIGIN_CITY_NAME ORIGIN_STATE_ABR DEST_CITY_NAME DEST_STATE_ABR  \
# 0              Las Vegas               NV        Chicago             IL
# ...

# %%
# Cargamos el dataset
dataclima = pd.read_csv('Weather.csv')

# %%
dataclima = pd.read_csv('Weather2020Mejorado.csv')

# %%
dataclima.drop('Unnamed: 0', inplace=True, axis=1)

# %%
#Visualizamos el Dataset
dataclima
# Out:
#            EventId   Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 0              W-1   Snow     Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2   Snow     Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3   Snow     Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4   Snow     Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5   Snow     Light  2016-01-08 13:54:00  2016-01-08 15:54:00
# ...            ...    ...       ...                  ...                  ...
# 7479160  W-7577193  Storm    Severe  2021-12-26 18:19:00  2021-12-26 18:29:00
# 7479161  W-7577194   Snow     Light  2021-12-26 18:29:00  2021-12-26 18:38:00
# 7479162  W-7577195   Snow     Light  2021-12-28 00:53:00  2021-12-28 02:27:00
# 7479163  W-7577196   Snow  Moderate  2021-12-28 02:27:00  2021-12-28 03:09:00
# 7479164  W-7577197   Snow     Light  2021-12-28 03:09:00  2021-12-28 03:19:00
#
# ...

# %%
#Se copia el dataset en otra variable para realizar modificaciones
dataclimafilt=dataclima

# %%
dataclimafilt['StartTime(UTC)']= pd.to_datetime(dataclimafilt['StartTime(UTC)'], format='%Y-%m-%d')

# %%
dataclimafilt
# Out:
#            EventId   Type  Severity      StartTime(UTC)         EndTime(UTC)  \
# 0              W-1   Snow     Light 2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2   Snow     Light 2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3   Snow     Light 2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4   Snow     Light 2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5   Snow     Light 2016-01-08 13:54:00  2016-01-08 15:54:00
# ...            ...    ...       ...                 ...                  ...
# 7479160  W-7577193  Storm    Severe 2021-12-26 18:19:00  2021-12-26 18:29:00
# 7479161  W-7577194   Snow     Light 2021-12-26 18:29:00  2021-12-26 18:38:00
# 7479162  W-7577195   Snow     Light 2021-12-28 00:53:00  2021-12-28 02:27:00
# 7479163  W-7577196   Snow  Moderate 2021-12-28 02:27:00  2021-12-28 03:09:00
# 7479164  W-7577197   Snow     Light 2021-12-28 03:09:00  2021-12-28 03:19:00
#
# ...

# %%
#Separamos la columna de Start Time  y End Time para trabajarlos mejor
dataclimafilt['StartDateOnly'] = [d.date() for d in dataclimafilt['StartTime(UTC)']]
dataclimafilt['StartTimeOnly'] = [d.time() for d in dataclimafilt['StartTime(UTC)']]

# %%
dataclimafilt
# Out:
#            EventId   Type  Severity      StartTime(UTC)         EndTime(UTC)  \
# 0              W-1   Snow     Light 2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2   Snow     Light 2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3   Snow     Light 2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4   Snow     Light 2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5   Snow     Light 2016-01-08 13:54:00  2016-01-08 15:54:00
# ...            ...    ...       ...                 ...                  ...
# 7479160  W-7577193  Storm    Severe 2021-12-26 18:19:00  2021-12-26 18:29:00
# 7479161  W-7577194   Snow     Light 2021-12-26 18:29:00  2021-12-26 18:38:00
# 7479162  W-7577195   Snow     Light 2021-12-28 00:53:00  2021-12-28 02:27:00
# 7479163  W-7577196   Snow  Moderate 2021-12-28 02:27:00  2021-12-28 03:09:00
# 7479164  W-7577197   Snow     Light 2021-12-28 03:09:00  2021-12-28 03:19:00
#
# ...

# %%
dataclimafilt['EndTime(UTC)']= pd.to_datetime(dataclimafilt['EndTime(UTC)'], format='%Y-%m-%d')

# %%
dataclimafilt['EndDateOnly'] = [d.date() for d in dataclimafilt['EndTime(UTC)']]
dataclimafilt['EndTimeOnly'] = [d.time() for d in dataclimafilt['EndTime(UTC)']]

# %%
dataclimafilt
# Out:
#            EventId   Type  Severity      StartTime(UTC)        EndTime(UTC)  \
# 0              W-1   Snow     Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1              W-2   Snow     Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2              W-3   Snow     Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3              W-4   Snow     Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4              W-5   Snow     Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ...            ...    ...       ...                 ...                 ...
# 7479160  W-7577193  Storm    Severe 2021-12-26 18:19:00 2021-12-26 18:29:00
# 7479161  W-7577194   Snow     Light 2021-12-26 18:29:00 2021-12-26 18:38:00
# 7479162  W-7577195   Snow     Light 2021-12-28 00:53:00 2021-12-28 02:27:00
# 7479163  W-7577196   Snow  Moderate 2021-12-28 02:27:00 2021-12-28 03:09:00
# 7479164  W-7577197   Snow     Light 2021-12-28 03:09:00 2021-12-28 03:19:00
#
# ...

# %%
dataclimafilt.to_csv (r'C:\Users\Wallace\Documents\Henry Data Science\PF\PF_DS\Desarrollo\Weather2020Mejorado.csv', header=True)

# %%
datavuelos
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  \
# 0        2020      1            17            5                WN
# 1        2020      1            17            5                WN
# 2        2020      1            17            5                WN
# 3        2020      1            17            5                WN
# 4        2020      1            17            5                WN
# ...       ...    ...           ...          ...               ...
# 4316992  2020     11            22            7                WN
# 4316993  2020     11            22            7                WN
# 4316994  2020     11            22            7                WN
# 4316995  2020     11            22            7                WN
# 4316996  2020     11            22            7                WN
#
#         ORIGIN_CITY_NAME ORIGIN_STATE_ABR DEST_CITY_NAME DEST_STATE_ABR  \
# 0              Las Vegas               NV        Chicago             IL
# ...

# %%
datavuelos.to_csv (r'C:\Users\Wallace\Documents\Henry Data Science\PF\PF_DS\Desarrollo\Vuelos2020Mejorado.csv', header=True)

# %% [markdown]
# ## `Pairplot`
#
# ### En esta instancia, emplearemos un paso fundamental dentro de todo **EDA** que nos muestra todas las relaciones entre las variables cuantitativas del dataframe que estemos trabajando. La importancia de este paso radica en que nos permite elegir las mejores variables predictoras para nuestro modelo.

# %%
sns.pairplot(datavuelos, hue="CANCELLED")
plt.show()

# %% [markdown]
# ### Aqui podemos visualizar la influencia de estas variables en la cancelacion de vuelos, notando que la fecha del segundo trimestre hay un aumento considerable en la cancelacion
